# %% [markdown]
# ### Part 1: Testing and Visualization of the PVWatts API and Results

# %%
import altair as alt
import json
import pandas as pd 
import os
import requests
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.environ.get("API_KEY")
FORMAT = "json"
PVWATTS_URL = f"https://developer.nrel.gov/api/pvwatts/v8.{FORMAT}"
print(f"Format of the output data: {FORMAT}")
# Out:
# Format of the output data: json

# %%
# %%time

payload = {
    "api_key": API_KEY,
    "system_capacity": 100, # 100KW 
    "module_type": 1, # 1 for modern AR coated modules 
    "losses": 0, # Losses in percent 
    "array_type": 1, # Fixed roof mounted 
    "tilt": 10, # Tilt angle for SG 
    "azimuth": 180, # Using default value for northern hemisphere
    "lat": 1.3521,
    "lon": 103.8198,
    "timeframe": "monthly"
}

response = requests.get(PVWATTS_URL, params=payload)
# Out:
# CPU times: user 96.4 ms, sys: 8.14 ms, total: 105 ms
# Wall time: 2.41 s

# %%
ac = response.json()["outputs"]["ac_monthly"]
ac
# Out:
# [13595.86792642625,
#  12824.48687594529,
#  13893.97854073981,
#  12297.7931032666,
#  11467.06028956225,
#  10121.88719681611,
#  11825.48818317086,
#  12178.29408970878,
#  12558.57553134672,
#  12202.10045298225,
#  10633.86751562907,
#  11314.9367854461]

# %%
source = pd.DataFrame({
    "Month": pd.date_range(start="01/01/2023", freq="M", periods=12*25, inclusive="both"),
    "AC Power": ac*25
})

# %%
alt.data_transformers.disable_max_rows()


alt.Chart(source).mark_line().encode(
    x="Month",
    y="AC Power"
).properties(width=1000, height=600)
# Out:
# alt.Chart(...)

# %%
# Adjust the year by year degradation rates to be 0.5% 
import numpy as np 
degradation_factor = np.linspace(start=0.97, stop=(0.97*0.995**25), num=(12*25))

# %%
source["Realistic AC Power"] = source["AC Power"] * degradation_factor

# %%
source
# Out:
#          Month      AC Power  Realistic AC Power
# 0   2023-01-31  13595.867926        13187.991889
# 1   2023-02-28  12824.486876        12434.852099
# 2   2023-03-31  13893.978541        13466.541549
# 3   2023-04-30  12297.793103        11914.762539
# 4   2023-05-31  11467.060290        11105.522462
# ..         ...           ...                 ...
# 295 2047-08-31  12178.294090        10440.232498
# 296 2047-09-30  12558.575531        10761.442371
# 297 2047-10-31  12202.100453        10451.316545
# 298 2047-11-30  10633.867516         9104.033934
# 299 2047-12-31  11314.936785         9682.798291
#
# [300 rows x 3 columns]

# %%
data = source.melt("Month")
data
# Out:
#          Month            variable         value
# 0   2023-01-31            AC Power  13595.867926
# 1   2023-02-28            AC Power  12824.486876
# 2   2023-03-31            AC Power  13893.978541
# 3   2023-04-30            AC Power  12297.793103
# 4   2023-05-31            AC Power  11467.060290
# ..         ...                 ...           ...
# 595 2047-08-31  Realistic AC Power  10440.232498
# 596 2047-09-30  Realistic AC Power  10761.442371
# 597 2047-10-31  Realistic AC Power  10451.316545
# 598 2047-11-30  Realistic AC Power   9104.033934
# 599 2047-12-31  Realistic AC Power   9682.798291
#
# [600 rows x 3 columns]

# %%
alt.data_transformers.disable_max_rows()

alt.Chart(data).mark_line().encode(
    x='Month',
    y='value',
    color='variable'
).interactive(
).properties(width=1000, height=600)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Part 2: Using Different Combinations of System Capacity, Module Type, Array Type and Tilt Angle to Get PVWatts Results

# %%
# Creating the configuration to generate more data 

payload = {
    "api_key": API_KEY,
    "system_capacity": 100, # 100KW 
    "module_type": 1, # 1 for modern AR coated modules 
    "losses": 0, # Losses in percent 
    "array_type": 1, # Fixed roof mounted 
    "tilt": 10, # Tilt angle for SG 
    "azimuth": 180, # Using default value for northern hemisphere
    "lat": 1.3521,
    "lon": 103.8198,
    "timeframe": "monthly"
}

capacity_list = [1, 10, 20, 30, 40, 50, 60, 70, 80, 90]
module_type_list = [0, 1, 2]
array_type_list = [0, 1]
tilt_list = [5, 10, 15, 30]

# %%
from itertools import product
payload_list = list(product(capacity_list, module_type_list, array_type_list, tilt_list))
print(f"There are {len(payload_list)} combinations of payload.")
# Out:
# There are 240 combinations of payload.

# %%
combi_count = 1

for combi in payload_list:
    payload["system_capacity"] = combi[0]
    payload["module_type"] = combi[1]
    payload["array_type"] = combi[2]
    payload["tilt"] = combi[3]
    
    print(f"Starting combi {combi_count} out of {len(payload_list)}")
    combi_count += 1
    
    print(f"Getting data using system_capacity {combi[0]}, module_type {combi[1]}, array_type {combi[2]} and tilt {combi[3]}")
    response = requests.get(PVWATTS_URL, params=payload)
    print(f"Saving json data for system_capacity {combi[0]}, module_type {combi[1]}, array_type {combi[2]} and tilt {combi[3]}")
    with open(f"data/pvwatts/raw_monthly/system_capacity{combi[0]}_module_type{combi[1]}_array_type{combi[2]}_tilt{combi[3]}.json", "w") as outfile:
        json.dump(response.json(), outfile)
    print("### Json data saved! ###")
# Out:
# Starting combi 1 out of 240
# Getting data using system_capacity 1, module_type 0, array_type 0 and tilt 5
# Saving json data for system_capacity 1, module_type 0, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 2 out of 240
# Getting data using system_capacity 1, module_type 0, array_type 0 and tilt 10
# Saving json data for system_capacity 1, module_type 0, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 3 out of 240
# Getting data using system_capacity 1, module_type 0, array_type 0 and tilt 15
# Saving json data for system_capacity 1, module_type 0, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 4 out of 240
# Getting data using system_capacity 1, module_type 0, array_type 0 and tilt 30
# Saving json data for system_capacity 1, module_type 0, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 5 out of 240
# Getting data using system_capacity 1, module_type 0, array_type 1 and tilt 5
# Saving json data for system_capacity 1, module_type 0, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 6 out of 240
# Getting data using system_capacity 1, module_type 0, array_type 1 and tilt 10
# Saving json data for system_capacity 1, module_type 0, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 7 out of 240
# Getting data using system_capacity 1, module_type 0, array_type 1 and tilt 15
# Saving json data for system_capacity 1, module_type 0, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 8 out of 240
# Getting data using system_capacity 1, module_type 0, array_type 1 and tilt 30
# Saving json data for system_capacity 1, module_type 0, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 9 out of 240
# Getting data using system_capacity 1, module_type 1, array_type 0 and tilt 5
# Saving json data for system_capacity 1, module_type 1, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 10 out of 240
# Getting data using system_capacity 1, module_type 1, array_type 0 and tilt 10
# Saving json data for system_capacity 1, module_type 1, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 11 out of 240
# Getting data using system_capacity 1, module_type 1, array_type 0 and tilt 15
# Saving json data for system_capacity 1, module_type 1, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 12 out of 240
# Getting data using system_capacity 1, module_type 1, array_type 0 and tilt 30
# Saving json data for system_capacity 1, module_type 1, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 13 out of 240
# Getting data using system_capacity 1, module_type 1, array_type 1 and tilt 5
# Saving json data for system_capacity 1, module_type 1, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 14 out of 240
# Getting data using system_capacity 1, module_type 1, array_type 1 and tilt 10
# Saving json data for system_capacity 1, module_type 1, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 15 out of 240
# Getting data using system_capacity 1, module_type 1, array_type 1 and tilt 15
# Saving json data for system_capacity 1, module_type 1, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 16 out of 240
# Getting data using system_capacity 1, module_type 1, array_type 1 and tilt 30
# Saving json data for system_capacity 1, module_type 1, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 17 out of 240
# Getting data using system_capacity 1, module_type 2, array_type 0 and tilt 5
# Saving json data for system_capacity 1, module_type 2, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 18 out of 240
# Getting data using system_capacity 1, module_type 2, array_type 0 and tilt 10
# Saving json data for system_capacity 1, module_type 2, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 19 out of 240
# Getting data using system_capacity 1, module_type 2, array_type 0 and tilt 15
# Saving json data for system_capacity 1, module_type 2, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 20 out of 240
# Getting data using system_capacity 1, module_type 2, array_type 0 and tilt 30
# Saving json data for system_capacity 1, module_type 2, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 21 out of 240
# Getting data using system_capacity 1, module_type 2, array_type 1 and tilt 5
# Saving json data for system_capacity 1, module_type 2, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 22 out of 240
# Getting data using system_capacity 1, module_type 2, array_type 1 and tilt 10
# Saving json data for system_capacity 1, module_type 2, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 23 out of 240
# Getting data using system_capacity 1, module_type 2, array_type 1 and tilt 15
# Saving json data for system_capacity 1, module_type 2, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 24 out of 240
# Getting data using system_capacity 1, module_type 2, array_type 1 and tilt 30
# Saving json data for system_capacity 1, module_type 2, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 25 out of 240
# Getting data using system_capacity 10, module_type 0, array_type 0 and tilt 5
# Saving json data for system_capacity 10, module_type 0, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 26 out of 240
# Getting data using system_capacity 10, module_type 0, array_type 0 and tilt 10
# Saving json data for system_capacity 10, module_type 0, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 27 out of 240
# Getting data using system_capacity 10, module_type 0, array_type 0 and tilt 15
# Saving json data for system_capacity 10, module_type 0, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 28 out of 240
# Getting data using system_capacity 10, module_type 0, array_type 0 and tilt 30
# Saving json data for system_capacity 10, module_type 0, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 29 out of 240
# Getting data using system_capacity 10, module_type 0, array_type 1 and tilt 5
# Saving json data for system_capacity 10, module_type 0, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 30 out of 240
# Getting data using system_capacity 10, module_type 0, array_type 1 and tilt 10
# Saving json data for system_capacity 10, module_type 0, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 31 out of 240
# Getting data using system_capacity 10, module_type 0, array_type 1 and tilt 15
# Saving json data for system_capacity 10, module_type 0, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 32 out of 240
# Getting data using system_capacity 10, module_type 0, array_type 1 and tilt 30
# Saving json data for system_capacity 10, module_type 0, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 33 out of 240
# Getting data using system_capacity 10, module_type 1, array_type 0 and tilt 5
# Saving json data for system_capacity 10, module_type 1, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 34 out of 240
# Getting data using system_capacity 10, module_type 1, array_type 0 and tilt 10
# Saving json data for system_capacity 10, module_type 1, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 35 out of 240
# Getting data using system_capacity 10, module_type 1, array_type 0 and tilt 15
# Saving json data for system_capacity 10, module_type 1, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 36 out of 240
# Getting data using system_capacity 10, module_type 1, array_type 0 and tilt 30
# Saving json data for system_capacity 10, module_type 1, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 37 out of 240
# Getting data using system_capacity 10, module_type 1, array_type 1 and tilt 5
# Saving json data for system_capacity 10, module_type 1, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 38 out of 240
# Getting data using system_capacity 10, module_type 1, array_type 1 and tilt 10
# Saving json data for system_capacity 10, module_type 1, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 39 out of 240
# Getting data using system_capacity 10, module_type 1, array_type 1 and tilt 15
# Saving json data for system_capacity 10, module_type 1, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 40 out of 240
# Getting data using system_capacity 10, module_type 1, array_type 1 and tilt 30
# Saving json data for system_capacity 10, module_type 1, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 41 out of 240
# Getting data using system_capacity 10, module_type 2, array_type 0 and tilt 5
# Saving json data for system_capacity 10, module_type 2, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 42 out of 240
# Getting data using system_capacity 10, module_type 2, array_type 0 and tilt 10
# Saving json data for system_capacity 10, module_type 2, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 43 out of 240
# Getting data using system_capacity 10, module_type 2, array_type 0 and tilt 15
# Saving json data for system_capacity 10, module_type 2, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 44 out of 240
# Getting data using system_capacity 10, module_type 2, array_type 0 and tilt 30
# Saving json data for system_capacity 10, module_type 2, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 45 out of 240
# Getting data using system_capacity 10, module_type 2, array_type 1 and tilt 5
# Saving json data for system_capacity 10, module_type 2, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 46 out of 240
# Getting data using system_capacity 10, module_type 2, array_type 1 and tilt 10
# Saving json data for system_capacity 10, module_type 2, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 47 out of 240
# Getting data using system_capacity 10, module_type 2, array_type 1 and tilt 15
# Saving json data for system_capacity 10, module_type 2, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 48 out of 240
# Getting data using system_capacity 10, module_type 2, array_type 1 and tilt 30
# Saving json data for system_capacity 10, module_type 2, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 49 out of 240
# Getting data using system_capacity 20, module_type 0, array_type 0 and tilt 5
# Saving json data for system_capacity 20, module_type 0, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 50 out of 240
# Getting data using system_capacity 20, module_type 0, array_type 0 and tilt 10
# Saving json data for system_capacity 20, module_type 0, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 51 out of 240
# Getting data using system_capacity 20, module_type 0, array_type 0 and tilt 15
# Saving json data for system_capacity 20, module_type 0, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 52 out of 240
# Getting data using system_capacity 20, module_type 0, array_type 0 and tilt 30
# Saving json data for system_capacity 20, module_type 0, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 53 out of 240
# Getting data using system_capacity 20, module_type 0, array_type 1 and tilt 5
# Saving json data for system_capacity 20, module_type 0, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 54 out of 240
# Getting data using system_capacity 20, module_type 0, array_type 1 and tilt 10
# Saving json data for system_capacity 20, module_type 0, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 55 out of 240
# Getting data using system_capacity 20, module_type 0, array_type 1 and tilt 15
# Saving json data for system_capacity 20, module_type 0, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 56 out of 240
# Getting data using system_capacity 20, module_type 0, array_type 1 and tilt 30
# Saving json data for system_capacity 20, module_type 0, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 57 out of 240
# Getting data using system_capacity 20, module_type 1, array_type 0 and tilt 5
# Saving json data for system_capacity 20, module_type 1, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 58 out of 240
# Getting data using system_capacity 20, module_type 1, array_type 0 and tilt 10
# Saving json data for system_capacity 20, module_type 1, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 59 out of 240
# Getting data using system_capacity 20, module_type 1, array_type 0 and tilt 15
# Saving json data for system_capacity 20, module_type 1, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 60 out of 240
# Getting data using system_capacity 20, module_type 1, array_type 0 and tilt 30
# Saving json data for system_capacity 20, module_type 1, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 61 out of 240
# Getting data using system_capacity 20, module_type 1, array_type 1 and tilt 5
# Saving json data for system_capacity 20, module_type 1, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 62 out of 240
# Getting data using system_capacity 20, module_type 1, array_type 1 and tilt 10
# Saving json data for system_capacity 20, module_type 1, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 63 out of 240
# Getting data using system_capacity 20, module_type 1, array_type 1 and tilt 15
# Saving json data for system_capacity 20, module_type 1, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 64 out of 240
# Getting data using system_capacity 20, module_type 1, array_type 1 and tilt 30
# Saving json data for system_capacity 20, module_type 1, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 65 out of 240
# Getting data using system_capacity 20, module_type 2, array_type 0 and tilt 5
# Saving json data for system_capacity 20, module_type 2, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 66 out of 240
# Getting data using system_capacity 20, module_type 2, array_type 0 and tilt 10
# Saving json data for system_capacity 20, module_type 2, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 67 out of 240
# Getting data using system_capacity 20, module_type 2, array_type 0 and tilt 15
# Saving json data for system_capacity 20, module_type 2, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 68 out of 240
# Getting data using system_capacity 20, module_type 2, array_type 0 and tilt 30
# Saving json data for system_capacity 20, module_type 2, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 69 out of 240
# Getting data using system_capacity 20, module_type 2, array_type 1 and tilt 5
# Saving json data for system_capacity 20, module_type 2, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 70 out of 240
# Getting data using system_capacity 20, module_type 2, array_type 1 and tilt 10
# Saving json data for system_capacity 20, module_type 2, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 71 out of 240
# Getting data using system_capacity 20, module_type 2, array_type 1 and tilt 15
# Saving json data for system_capacity 20, module_type 2, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 72 out of 240
# Getting data using system_capacity 20, module_type 2, array_type 1 and tilt 30
# Saving json data for system_capacity 20, module_type 2, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 73 out of 240
# Getting data using system_capacity 30, module_type 0, array_type 0 and tilt 5
# Saving json data for system_capacity 30, module_type 0, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 74 out of 240
# Getting data using system_capacity 30, module_type 0, array_type 0 and tilt 10
# Saving json data for system_capacity 30, module_type 0, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 75 out of 240
# Getting data using system_capacity 30, module_type 0, array_type 0 and tilt 15
# Saving json data for system_capacity 30, module_type 0, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 76 out of 240
# Getting data using system_capacity 30, module_type 0, array_type 0 and tilt 30
# Saving json data for system_capacity 30, module_type 0, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 77 out of 240
# Getting data using system_capacity 30, module_type 0, array_type 1 and tilt 5
# Saving json data for system_capacity 30, module_type 0, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 78 out of 240
# Getting data using system_capacity 30, module_type 0, array_type 1 and tilt 10
# Saving json data for system_capacity 30, module_type 0, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 79 out of 240
# Getting data using system_capacity 30, module_type 0, array_type 1 and tilt 15
# Saving json data for system_capacity 30, module_type 0, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 80 out of 240
# Getting data using system_capacity 30, module_type 0, array_type 1 and tilt 30
# Saving json data for system_capacity 30, module_type 0, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 81 out of 240
# Getting data using system_capacity 30, module_type 1, array_type 0 and tilt 5
# Saving json data for system_capacity 30, module_type 1, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 82 out of 240
# Getting data using system_capacity 30, module_type 1, array_type 0 and tilt 10
# Saving json data for system_capacity 30, module_type 1, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 83 out of 240
# Getting data using system_capacity 30, module_type 1, array_type 0 and tilt 15
# Saving json data for system_capacity 30, module_type 1, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 84 out of 240
# Getting data using system_capacity 30, module_type 1, array_type 0 and tilt 30
# Saving json data for system_capacity 30, module_type 1, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 85 out of 240
# Getting data using system_capacity 30, module_type 1, array_type 1 and tilt 5
# Saving json data for system_capacity 30, module_type 1, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 86 out of 240
# Getting data using system_capacity 30, module_type 1, array_type 1 and tilt 10
# Saving json data for system_capacity 30, module_type 1, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 87 out of 240
# Getting data using system_capacity 30, module_type 1, array_type 1 and tilt 15
# Saving json data for system_capacity 30, module_type 1, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 88 out of 240
# Getting data using system_capacity 30, module_type 1, array_type 1 and tilt 30
# Saving json data for system_capacity 30, module_type 1, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 89 out of 240
# Getting data using system_capacity 30, module_type 2, array_type 0 and tilt 5
# Saving json data for system_capacity 30, module_type 2, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 90 out of 240
# Getting data using system_capacity 30, module_type 2, array_type 0 and tilt 10
# Saving json data for system_capacity 30, module_type 2, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 91 out of 240
# Getting data using system_capacity 30, module_type 2, array_type 0 and tilt 15
# Saving json data for system_capacity 30, module_type 2, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 92 out of 240
# Getting data using system_capacity 30, module_type 2, array_type 0 and tilt 30
# Saving json data for system_capacity 30, module_type 2, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 93 out of 240
# Getting data using system_capacity 30, module_type 2, array_type 1 and tilt 5
# Saving json data for system_capacity 30, module_type 2, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 94 out of 240
# Getting data using system_capacity 30, module_type 2, array_type 1 and tilt 10
# Saving json data for system_capacity 30, module_type 2, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 95 out of 240
# Getting data using system_capacity 30, module_type 2, array_type 1 and tilt 15
# Saving json data for system_capacity 30, module_type 2, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 96 out of 240
# Getting data using system_capacity 30, module_type 2, array_type 1 and tilt 30
# Saving json data for system_capacity 30, module_type 2, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 97 out of 240
# Getting data using system_capacity 40, module_type 0, array_type 0 and tilt 5
# Saving json data for system_capacity 40, module_type 0, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 98 out of 240
# Getting data using system_capacity 40, module_type 0, array_type 0 and tilt 10
# Saving json data for system_capacity 40, module_type 0, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 99 out of 240
# Getting data using system_capacity 40, module_type 0, array_type 0 and tilt 15
# Saving json data for system_capacity 40, module_type 0, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 100 out of 240
# Getting data using system_capacity 40, module_type 0, array_type 0 and tilt 30
# Saving json data for system_capacity 40, module_type 0, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 101 out of 240
# Getting data using system_capacity 40, module_type 0, array_type 1 and tilt 5
# Saving json data for system_capacity 40, module_type 0, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 102 out of 240
# Getting data using system_capacity 40, module_type 0, array_type 1 and tilt 10
# Saving json data for system_capacity 40, module_type 0, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 103 out of 240
# Getting data using system_capacity 40, module_type 0, array_type 1 and tilt 15
# Saving json data for system_capacity 40, module_type 0, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 104 out of 240
# Getting data using system_capacity 40, module_type 0, array_type 1 and tilt 30
# Saving json data for system_capacity 40, module_type 0, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 105 out of 240
# Getting data using system_capacity 40, module_type 1, array_type 0 and tilt 5
# Saving json data for system_capacity 40, module_type 1, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 106 out of 240
# Getting data using system_capacity 40, module_type 1, array_type 0 and tilt 10
# Saving json data for system_capacity 40, module_type 1, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 107 out of 240
# Getting data using system_capacity 40, module_type 1, array_type 0 and tilt 15
# Saving json data for system_capacity 40, module_type 1, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 108 out of 240
# Getting data using system_capacity 40, module_type 1, array_type 0 and tilt 30
# Saving json data for system_capacity 40, module_type 1, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 109 out of 240
# Getting data using system_capacity 40, module_type 1, array_type 1 and tilt 5
# Saving json data for system_capacity 40, module_type 1, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 110 out of 240
# Getting data using system_capacity 40, module_type 1, array_type 1 and tilt 10
# Saving json data for system_capacity 40, module_type 1, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 111 out of 240
# Getting data using system_capacity 40, module_type 1, array_type 1 and tilt 15
# Saving json data for system_capacity 40, module_type 1, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 112 out of 240
# Getting data using system_capacity 40, module_type 1, array_type 1 and tilt 30
# Saving json data for system_capacity 40, module_type 1, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 113 out of 240
# Getting data using system_capacity 40, module_type 2, array_type 0 and tilt 5
# Saving json data for system_capacity 40, module_type 2, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 114 out of 240
# Getting data using system_capacity 40, module_type 2, array_type 0 and tilt 10
# Saving json data for system_capacity 40, module_type 2, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 115 out of 240
# Getting data using system_capacity 40, module_type 2, array_type 0 and tilt 15
# Saving json data for system_capacity 40, module_type 2, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 116 out of 240
# Getting data using system_capacity 40, module_type 2, array_type 0 and tilt 30
# Saving json data for system_capacity 40, module_type 2, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 117 out of 240
# Getting data using system_capacity 40, module_type 2, array_type 1 and tilt 5
# Saving json data for system_capacity 40, module_type 2, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 118 out of 240
# Getting data using system_capacity 40, module_type 2, array_type 1 and tilt 10
# Saving json data for system_capacity 40, module_type 2, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 119 out of 240
# Getting data using system_capacity 40, module_type 2, array_type 1 and tilt 15
# Saving json data for system_capacity 40, module_type 2, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 120 out of 240
# Getting data using system_capacity 40, module_type 2, array_type 1 and tilt 30
# Saving json data for system_capacity 40, module_type 2, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 121 out of 240
# Getting data using system_capacity 50, module_type 0, array_type 0 and tilt 5
# Saving json data for system_capacity 50, module_type 0, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 122 out of 240
# Getting data using system_capacity 50, module_type 0, array_type 0 and tilt 10
# Saving json data for system_capacity 50, module_type 0, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 123 out of 240
# Getting data using system_capacity 50, module_type 0, array_type 0 and tilt 15
# Saving json data for system_capacity 50, module_type 0, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 124 out of 240
# Getting data using system_capacity 50, module_type 0, array_type 0 and tilt 30
# Saving json data for system_capacity 50, module_type 0, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 125 out of 240
# Getting data using system_capacity 50, module_type 0, array_type 1 and tilt 5
# Saving json data for system_capacity 50, module_type 0, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 126 out of 240
# Getting data using system_capacity 50, module_type 0, array_type 1 and tilt 10
# Saving json data for system_capacity 50, module_type 0, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 127 out of 240
# Getting data using system_capacity 50, module_type 0, array_type 1 and tilt 15
# Saving json data for system_capacity 50, module_type 0, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 128 out of 240
# Getting data using system_capacity 50, module_type 0, array_type 1 and tilt 30
# Saving json data for system_capacity 50, module_type 0, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 129 out of 240
# Getting data using system_capacity 50, module_type 1, array_type 0 and tilt 5
# Saving json data for system_capacity 50, module_type 1, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 130 out of 240
# Getting data using system_capacity 50, module_type 1, array_type 0 and tilt 10
# Saving json data for system_capacity 50, module_type 1, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 131 out of 240
# Getting data using system_capacity 50, module_type 1, array_type 0 and tilt 15
# Saving json data for system_capacity 50, module_type 1, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 132 out of 240
# Getting data using system_capacity 50, module_type 1, array_type 0 and tilt 30
# Saving json data for system_capacity 50, module_type 1, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 133 out of 240
# Getting data using system_capacity 50, module_type 1, array_type 1 and tilt 5
# Saving json data for system_capacity 50, module_type 1, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 134 out of 240
# Getting data using system_capacity 50, module_type 1, array_type 1 and tilt 10
# Saving json data for system_capacity 50, module_type 1, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 135 out of 240
# Getting data using system_capacity 50, module_type 1, array_type 1 and tilt 15
# Saving json data for system_capacity 50, module_type 1, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 136 out of 240
# Getting data using system_capacity 50, module_type 1, array_type 1 and tilt 30
# Saving json data for system_capacity 50, module_type 1, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 137 out of 240
# Getting data using system_capacity 50, module_type 2, array_type 0 and tilt 5
# Saving json data for system_capacity 50, module_type 2, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 138 out of 240
# Getting data using system_capacity 50, module_type 2, array_type 0 and tilt 10
# Saving json data for system_capacity 50, module_type 2, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 139 out of 240
# Getting data using system_capacity 50, module_type 2, array_type 0 and tilt 15
# Saving json data for system_capacity 50, module_type 2, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 140 out of 240
# Getting data using system_capacity 50, module_type 2, array_type 0 and tilt 30
# Saving json data for system_capacity 50, module_type 2, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 141 out of 240
# Getting data using system_capacity 50, module_type 2, array_type 1 and tilt 5
# Saving json data for system_capacity 50, module_type 2, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 142 out of 240
# Getting data using system_capacity 50, module_type 2, array_type 1 and tilt 10
# Saving json data for system_capacity 50, module_type 2, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 143 out of 240
# Getting data using system_capacity 50, module_type 2, array_type 1 and tilt 15
# Saving json data for system_capacity 50, module_type 2, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 144 out of 240
# Getting data using system_capacity 50, module_type 2, array_type 1 and tilt 30
# Saving json data for system_capacity 50, module_type 2, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 145 out of 240
# Getting data using system_capacity 60, module_type 0, array_type 0 and tilt 5
# Saving json data for system_capacity 60, module_type 0, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 146 out of 240
# Getting data using system_capacity 60, module_type 0, array_type 0 and tilt 10
# Saving json data for system_capacity 60, module_type 0, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 147 out of 240
# Getting data using system_capacity 60, module_type 0, array_type 0 and tilt 15
# Saving json data for system_capacity 60, module_type 0, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 148 out of 240
# Getting data using system_capacity 60, module_type 0, array_type 0 and tilt 30
# Saving json data for system_capacity 60, module_type 0, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 149 out of 240
# Getting data using system_capacity 60, module_type 0, array_type 1 and tilt 5
# Saving json data for system_capacity 60, module_type 0, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 150 out of 240
# Getting data using system_capacity 60, module_type 0, array_type 1 and tilt 10
# Saving json data for system_capacity 60, module_type 0, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 151 out of 240
# Getting data using system_capacity 60, module_type 0, array_type 1 and tilt 15
# Saving json data for system_capacity 60, module_type 0, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 152 out of 240
# Getting data using system_capacity 60, module_type 0, array_type 1 and tilt 30
# Saving json data for system_capacity 60, module_type 0, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 153 out of 240
# Getting data using system_capacity 60, module_type 1, array_type 0 and tilt 5
# Saving json data for system_capacity 60, module_type 1, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 154 out of 240
# Getting data using system_capacity 60, module_type 1, array_type 0 and tilt 10
# Saving json data for system_capacity 60, module_type 1, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 155 out of 240
# Getting data using system_capacity 60, module_type 1, array_type 0 and tilt 15
# Saving json data for system_capacity 60, module_type 1, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 156 out of 240
# Getting data using system_capacity 60, module_type 1, array_type 0 and tilt 30
# Saving json data for system_capacity 60, module_type 1, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 157 out of 240
# Getting data using system_capacity 60, module_type 1, array_type 1 and tilt 5
# Saving json data for system_capacity 60, module_type 1, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 158 out of 240
# Getting data using system_capacity 60, module_type 1, array_type 1 and tilt 10
# Saving json data for system_capacity 60, module_type 1, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 159 out of 240
# Getting data using system_capacity 60, module_type 1, array_type 1 and tilt 15
# Saving json data for system_capacity 60, module_type 1, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 160 out of 240
# Getting data using system_capacity 60, module_type 1, array_type 1 and tilt 30
# Saving json data for system_capacity 60, module_type 1, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 161 out of 240
# Getting data using system_capacity 60, module_type 2, array_type 0 and tilt 5
# Saving json data for system_capacity 60, module_type 2, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 162 out of 240
# Getting data using system_capacity 60, module_type 2, array_type 0 and tilt 10
# Saving json data for system_capacity 60, module_type 2, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 163 out of 240
# Getting data using system_capacity 60, module_type 2, array_type 0 and tilt 15
# Saving json data for system_capacity 60, module_type 2, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 164 out of 240
# Getting data using system_capacity 60, module_type 2, array_type 0 and tilt 30
# Saving json data for system_capacity 60, module_type 2, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 165 out of 240
# Getting data using system_capacity 60, module_type 2, array_type 1 and tilt 5
# Saving json data for system_capacity 60, module_type 2, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 166 out of 240
# Getting data using system_capacity 60, module_type 2, array_type 1 and tilt 10
# Saving json data for system_capacity 60, module_type 2, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 167 out of 240
# Getting data using system_capacity 60, module_type 2, array_type 1 and tilt 15
# Saving json data for system_capacity 60, module_type 2, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 168 out of 240
# Getting data using system_capacity 60, module_type 2, array_type 1 and tilt 30
# Saving json data for system_capacity 60, module_type 2, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 169 out of 240
# Getting data using system_capacity 70, module_type 0, array_type 0 and tilt 5
# Saving json data for system_capacity 70, module_type 0, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 170 out of 240
# Getting data using system_capacity 70, module_type 0, array_type 0 and tilt 10
# Saving json data for system_capacity 70, module_type 0, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 171 out of 240
# Getting data using system_capacity 70, module_type 0, array_type 0 and tilt 15
# Saving json data for system_capacity 70, module_type 0, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 172 out of 240
# Getting data using system_capacity 70, module_type 0, array_type 0 and tilt 30
# Saving json data for system_capacity 70, module_type 0, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 173 out of 240
# Getting data using system_capacity 70, module_type 0, array_type 1 and tilt 5
# Saving json data for system_capacity 70, module_type 0, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 174 out of 240
# Getting data using system_capacity 70, module_type 0, array_type 1 and tilt 10
# Saving json data for system_capacity 70, module_type 0, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 175 out of 240
# Getting data using system_capacity 70, module_type 0, array_type 1 and tilt 15
# Saving json data for system_capacity 70, module_type 0, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 176 out of 240
# Getting data using system_capacity 70, module_type 0, array_type 1 and tilt 30
# Saving json data for system_capacity 70, module_type 0, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 177 out of 240
# Getting data using system_capacity 70, module_type 1, array_type 0 and tilt 5
# Saving json data for system_capacity 70, module_type 1, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 178 out of 240
# Getting data using system_capacity 70, module_type 1, array_type 0 and tilt 10
# Saving json data for system_capacity 70, module_type 1, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 179 out of 240
# Getting data using system_capacity 70, module_type 1, array_type 0 and tilt 15
# Saving json data for system_capacity 70, module_type 1, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 180 out of 240
# Getting data using system_capacity 70, module_type 1, array_type 0 and tilt 30
# Saving json data for system_capacity 70, module_type 1, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 181 out of 240
# Getting data using system_capacity 70, module_type 1, array_type 1 and tilt 5
# Saving json data for system_capacity 70, module_type 1, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 182 out of 240
# Getting data using system_capacity 70, module_type 1, array_type 1 and tilt 10
# Saving json data for system_capacity 70, module_type 1, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 183 out of 240
# Getting data using system_capacity 70, module_type 1, array_type 1 and tilt 15
# Saving json data for system_capacity 70, module_type 1, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 184 out of 240
# Getting data using system_capacity 70, module_type 1, array_type 1 and tilt 30
# Saving json data for system_capacity 70, module_type 1, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 185 out of 240
# Getting data using system_capacity 70, module_type 2, array_type 0 and tilt 5
# Saving json data for system_capacity 70, module_type 2, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 186 out of 240
# Getting data using system_capacity 70, module_type 2, array_type 0 and tilt 10
# Saving json data for system_capacity 70, module_type 2, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 187 out of 240
# Getting data using system_capacity 70, module_type 2, array_type 0 and tilt 15
# Saving json data for system_capacity 70, module_type 2, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 188 out of 240
# Getting data using system_capacity 70, module_type 2, array_type 0 and tilt 30
# Saving json data for system_capacity 70, module_type 2, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 189 out of 240
# Getting data using system_capacity 70, module_type 2, array_type 1 and tilt 5
# Saving json data for system_capacity 70, module_type 2, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 190 out of 240
# Getting data using system_capacity 70, module_type 2, array_type 1 and tilt 10
# Saving json data for system_capacity 70, module_type 2, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 191 out of 240
# Getting data using system_capacity 70, module_type 2, array_type 1 and tilt 15
# Saving json data for system_capacity 70, module_type 2, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 192 out of 240
# Getting data using system_capacity 70, module_type 2, array_type 1 and tilt 30
# Saving json data for system_capacity 70, module_type 2, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 193 out of 240
# Getting data using system_capacity 80, module_type 0, array_type 0 and tilt 5
# Saving json data for system_capacity 80, module_type 0, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 194 out of 240
# Getting data using system_capacity 80, module_type 0, array_type 0 and tilt 10
# Saving json data for system_capacity 80, module_type 0, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 195 out of 240
# Getting data using system_capacity 80, module_type 0, array_type 0 and tilt 15
# Saving json data for system_capacity 80, module_type 0, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 196 out of 240
# Getting data using system_capacity 80, module_type 0, array_type 0 and tilt 30
# Saving json data for system_capacity 80, module_type 0, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 197 out of 240
# Getting data using system_capacity 80, module_type 0, array_type 1 and tilt 5
# Saving json data for system_capacity 80, module_type 0, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 198 out of 240
# Getting data using system_capacity 80, module_type 0, array_type 1 and tilt 10
# Saving json data for system_capacity 80, module_type 0, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 199 out of 240
# Getting data using system_capacity 80, module_type 0, array_type 1 and tilt 15
# Saving json data for system_capacity 80, module_type 0, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 200 out of 240
# Getting data using system_capacity 80, module_type 0, array_type 1 and tilt 30
# Saving json data for system_capacity 80, module_type 0, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 201 out of 240
# Getting data using system_capacity 80, module_type 1, array_type 0 and tilt 5
# Saving json data for system_capacity 80, module_type 1, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 202 out of 240
# Getting data using system_capacity 80, module_type 1, array_type 0 and tilt 10
# Saving json data for system_capacity 80, module_type 1, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 203 out of 240
# Getting data using system_capacity 80, module_type 1, array_type 0 and tilt 15
# Saving json data for system_capacity 80, module_type 1, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 204 out of 240
# Getting data using system_capacity 80, module_type 1, array_type 0 and tilt 30
# Saving json data for system_capacity 80, module_type 1, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 205 out of 240
# Getting data using system_capacity 80, module_type 1, array_type 1 and tilt 5
# Saving json data for system_capacity 80, module_type 1, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 206 out of 240
# Getting data using system_capacity 80, module_type 1, array_type 1 and tilt 10
# Saving json data for system_capacity 80, module_type 1, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 207 out of 240
# Getting data using system_capacity 80, module_type 1, array_type 1 and tilt 15
# Saving json data for system_capacity 80, module_type 1, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 208 out of 240
# Getting data using system_capacity 80, module_type 1, array_type 1 and tilt 30
# Saving json data for system_capacity 80, module_type 1, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 209 out of 240
# Getting data using system_capacity 80, module_type 2, array_type 0 and tilt 5
# Saving json data for system_capacity 80, module_type 2, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 210 out of 240
# Getting data using system_capacity 80, module_type 2, array_type 0 and tilt 10
# Saving json data for system_capacity 80, module_type 2, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 211 out of 240
# Getting data using system_capacity 80, module_type 2, array_type 0 and tilt 15
# Saving json data for system_capacity 80, module_type 2, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 212 out of 240
# Getting data using system_capacity 80, module_type 2, array_type 0 and tilt 30
# Saving json data for system_capacity 80, module_type 2, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 213 out of 240
# Getting data using system_capacity 80, module_type 2, array_type 1 and tilt 5
# Saving json data for system_capacity 80, module_type 2, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 214 out of 240
# Getting data using system_capacity 80, module_type 2, array_type 1 and tilt 10
# Saving json data for system_capacity 80, module_type 2, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 215 out of 240
# Getting data using system_capacity 80, module_type 2, array_type 1 and tilt 15
# Saving json data for system_capacity 80, module_type 2, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 216 out of 240
# Getting data using system_capacity 80, module_type 2, array_type 1 and tilt 30
# Saving json data for system_capacity 80, module_type 2, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 217 out of 240
# Getting data using system_capacity 90, module_type 0, array_type 0 and tilt 5
# Saving json data for system_capacity 90, module_type 0, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 218 out of 240
# Getting data using system_capacity 90, module_type 0, array_type 0 and tilt 10
# Saving json data for system_capacity 90, module_type 0, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 219 out of 240
# Getting data using system_capacity 90, module_type 0, array_type 0 and tilt 15
# Saving json data for system_capacity 90, module_type 0, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 220 out of 240
# Getting data using system_capacity 90, module_type 0, array_type 0 and tilt 30
# Saving json data for system_capacity 90, module_type 0, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 221 out of 240
# Getting data using system_capacity 90, module_type 0, array_type 1 and tilt 5
# Saving json data for system_capacity 90, module_type 0, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 222 out of 240
# Getting data using system_capacity 90, module_type 0, array_type 1 and tilt 10
# Saving json data for system_capacity 90, module_type 0, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 223 out of 240
# Getting data using system_capacity 90, module_type 0, array_type 1 and tilt 15
# Saving json data for system_capacity 90, module_type 0, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 224 out of 240
# Getting data using system_capacity 90, module_type 0, array_type 1 and tilt 30
# Saving json data for system_capacity 90, module_type 0, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 225 out of 240
# Getting data using system_capacity 90, module_type 1, array_type 0 and tilt 5
# Saving json data for system_capacity 90, module_type 1, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 226 out of 240
# Getting data using system_capacity 90, module_type 1, array_type 0 and tilt 10
# Saving json data for system_capacity 90, module_type 1, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 227 out of 240
# Getting data using system_capacity 90, module_type 1, array_type 0 and tilt 15
# Saving json data for system_capacity 90, module_type 1, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 228 out of 240
# Getting data using system_capacity 90, module_type 1, array_type 0 and tilt 30
# Saving json data for system_capacity 90, module_type 1, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 229 out of 240
# Getting data using system_capacity 90, module_type 1, array_type 1 and tilt 5
# Saving json data for system_capacity 90, module_type 1, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 230 out of 240
# Getting data using system_capacity 90, module_type 1, array_type 1 and tilt 10
# Saving json data for system_capacity 90, module_type 1, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 231 out of 240
# Getting data using system_capacity 90, module_type 1, array_type 1 and tilt 15
# Saving json data for system_capacity 90, module_type 1, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 232 out of 240
# Getting data using system_capacity 90, module_type 1, array_type 1 and tilt 30
# Saving json data for system_capacity 90, module_type 1, array_type 1 and tilt 30
# ### Json data saved! ###
# Starting combi 233 out of 240
# Getting data using system_capacity 90, module_type 2, array_type 0 and tilt 5
# Saving json data for system_capacity 90, module_type 2, array_type 0 and tilt 5
# ### Json data saved! ###
# Starting combi 234 out of 240
# Getting data using system_capacity 90, module_type 2, array_type 0 and tilt 10
# Saving json data for system_capacity 90, module_type 2, array_type 0 and tilt 10
# ### Json data saved! ###
# Starting combi 235 out of 240
# Getting data using system_capacity 90, module_type 2, array_type 0 and tilt 15
# Saving json data for system_capacity 90, module_type 2, array_type 0 and tilt 15
# ### Json data saved! ###
# Starting combi 236 out of 240
# Getting data using system_capacity 90, module_type 2, array_type 0 and tilt 30
# Saving json data for system_capacity 90, module_type 2, array_type 0 and tilt 30
# ### Json data saved! ###
# Starting combi 237 out of 240
# Getting data using system_capacity 90, module_type 2, array_type 1 and tilt 5
# Saving json data for system_capacity 90, module_type 2, array_type 1 and tilt 5
# ### Json data saved! ###
# Starting combi 238 out of 240
# Getting data using system_capacity 90, module_type 2, array_type 1 and tilt 10
# Saving json data for system_capacity 90, module_type 2, array_type 1 and tilt 10
# ### Json data saved! ###
# Starting combi 239 out of 240
# Getting data using system_capacity 90, module_type 2, array_type 1 and tilt 15
# Saving json data for system_capacity 90, module_type 2, array_type 1 and tilt 15
# ### Json data saved! ###
# Starting combi 240 out of 240
# Getting data using system_capacity 90, module_type 2, array_type 1 and tilt 30
# Saving json data for system_capacity 90, module_type 2, array_type 1 and tilt 30
# ### Json data saved! ###

# %%
from pathlib import Path

DATA_DIR = "./data/pvwatts/raw_monthly/"
DATA_PATH = Path(DATA_DIR)

counter = 0
for file in DATA_PATH.iterdir():
    if file.is_file():
        counter += 1

print(f"Total Files: {counter}")
# Out:
# Total Files: 240
